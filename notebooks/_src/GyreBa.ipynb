# %% [markdown]
# Notebook to show Ba (totally made up) in Gyre Simulation
#
# - Ba is added to surface, from 0-20 in x-direction and 0-20 in y-direction

# %%
import matplotlib.pyplot as plt
import netCDF4 as nc
import numpy as np
# %matplotlib inline

# %%
data = nc.Dataset('GYRE_5d_00010101_00011230_ptrc_T.nc','r')

# %%
print data.variables.keys()
# Out:
# [u'nav_lon', u'nav_lat', u'deptht', u'time_counter', u'time_counter_bnds', u'TR_7', u'DET', u'ZOO', u'PHY', u'NO3', u'NH4', u'DOM']

# %%
Ba = data.variables['TR_7']
print Ba.shape
# Out:
# (71, 31, 22, 32)

# %%
print Ba[0,0,5,5]
print Ba[1,0,5,5]
print Ba[2,0,5,5]
# Out:
# 0.000829835
# 0.00198524
# 0.00326095

# %%
plt.plot(Ba[0:71,0,5,5],'*-')

# %%
plt.pcolormesh(Ba[10,5])
plt.colorbar()
plt.xlim((1,30))
plt.ylim((1,20))
# Out:
# (1, 20)

# %%
plt.plot(Ba[:,5,5,5])
