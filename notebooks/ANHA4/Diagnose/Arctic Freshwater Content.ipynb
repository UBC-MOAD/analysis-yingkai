# %% [markdown]
# #Arctic freshwater analysis

# %% [markdown]
# This is the notebook that I used to calculate freshwater content and investgate its relation with AO. Bascally I found nothing by using ECMWF's ORAS4 dataset and I don't want to do more.

# %%
import glob
import scipy.io
import datetime
import numpy as np
import netCDF4 as nc
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
% matplotlib inline

# %%
RB=[0.25, 0.41, 0.88]    # Royal blue
AM=[0.90, 0.17, 0.31]    # Amathran
CamB = [0.64, 0.76, 0.68]# Cambridge blue

# %% [markdown]
# $$
# FWC = \int^{0}_{z_{lim}}{\left( 1-\frac{S(z)}{S_{ref}} \right)dz}
# $$
#
# * $S_{ref}$ is 34.8 as the end-member of Atlantic water
# * $S(z)$ is the salinity profile as a function of $z$
# * $z_{lim}$ first level of $S\left(z_{lim}\right) \geq S_{ref}$

# %%
def fwc_1d(S, z, Sref):
    if S[0] < Sref:
        id_lim = np.min(np.searchsorted(S, Sref, 'left'))
        fun = 1-S[:id_lim]/Sref
        return np.trapz(fun, x=z[:id_lim])
    else:
        return np.nan
def fwc_2d(S, z, Sref):
    fwc = np.empty(S.shape)[0, :, :]
    for i in range(np.size(S, 1)):
        for j in range(np.size(S, 2)):
            fwc[i, j] = fwc_1d(S[:, i, j], z, Sref)
    return fwc

# %% [markdown]
# # A test: WOA 1996 - 2005 climatology

# %%
JJA_name=glob.glob('../../_data/Reanalysis/WOA/*s13*.nc')
DJF_name=glob.glob('../../_data/Reanalysis/WOA/*s15*.nc')

# %%
JJA_obj=nc.Dataset(JJA_name[0])
DJF_obj=nc.Dataset(DJF_name[0])
print('Variables in {}:\n==============================================\n{}'.format(JJA_name[0], JJA_obj.variables.keys()))

# %%
lon=JJA_obj.variables['lon'][:]
lat=JJA_obj.variables['lat'][:]
JJA=JJA_obj.variables['s_an'][:]
DJF=DJF_obj.variables['s_an'][:]
depth=JJA_obj.variables['depth'][:]
longitude, latitude = np.meshgrid(lon, lat)

# %%
longitude.shape
# Out:
# (180L, 360L)

# %%
fwc_JJA = fwc_2d(JJA[0, :, :, :], depth, 34.8)
fwc_DJF = fwc_2d(DJF[0, :, :, :], depth, 34.8)

# %%
fwc_JJA_mask = np.ma.masked_where(np.isnan(fwc_JJA), fwc_JJA)
fwc_DJF_mask = np.ma.masked_where(np.isnan(fwc_DJF), fwc_DJF)

# %%
fig = plt.figure(figsize=(14, 14))
ax1 = plt.subplot2grid((1, 2), (0, 0), colspan=1, rowspan=1)
ax2 = plt.subplot2grid((1, 2), (0, 1), colspan=1, rowspan=1)

proj=Basemap(projection='npstere', resolution='c', boundinglat=60, lon_0=90, round=True, ax=ax1)
proj.drawmeridians(np.arange(0, 360, 60), labels=[1, 1, 1, 1], fontsize=10, latmax=90,linewidth=0)
proj.fillcontinents(color=[0.5, 0.5, 0.5], lake_color=None)
proj.drawcoastlines(linewidth=2.0, linestyle='-', color='k')
x, y=proj(longitude, latitude)
CS = proj.contourf(x, y, fwc_JJA_mask, range(0, 22, 2), extend='max')
ax1.set_title('(a) JJA')

ax = fig.gca()
proj=Basemap(projection='npstere', resolution='c', boundinglat=60, lon_0=90, round=True, ax=ax2)
proj.drawmeridians(np.arange(0, 360, 60), labels=[1, 1, 1, 1], fontsize=10, latmax=90,linewidth=0)
proj.fillcontinents(color=[0.5, 0.5, 0.5], lake_color=None)
proj.drawcoastlines(linewidth=2.0, linestyle='-', color='k')
x, y=proj(longitude, latitude)
CS = proj.contourf(x, y, fwc_DJF_mask, range(0, 22, 2), extend='max')
ax2.set_title('(b) DJF')

cax  = fig.add_axes([0.25, 0.3, 0.5, 0.015])
CBar = fig.colorbar(CS, cax=cax, orientation='horizontal')
CBar.set_label('Freshwater Content (m)', fontsize=12)

# %% [markdown]
# # Calculation based on ANHA4 salinity

# %%
SName = sorted(glob.glob('../../_data/MAT files/vosaline_by_month/vosaline*mat'))

# %%
dep_name = '/ocean/yingkai/GEOTRACES/NEMO-CODE/NEMOGCM/CONFIG/ANHA4_OFF/EXP00/mesh_zgr.nc'
dep_obj = nc.Dataset(dep_name)
deptht = dep_obj.variables['nav_lev'][:]

# MY_TRC domain
MAT = scipy.io.loadmat('../../_data/Exchange/Ba_boundary_ANHA4.mat')
domain = MAT['domain'][:].T

# %%
deptht[10]
# Out:
# 15.810073

# %%
FWC = np.zeros([800, 544])
FWC[FWC==0]=np.nan
print('allocation done')

# Loops
for time in range(144):
    vosaline = scipy.io.loadmat(SName[time])['vosaline'][:]
    for i in range(800):
        for j in range(544):
            if(domain[i, j]!=0):
                #print('Catch: {}, {}'.format(i, j))
                FWC[i, j] = fwc_1d(vosaline[:24, i, j], deptht[:24], Sref=34.8)
                # Save
    save_var = { 'FWC': FWC}
    scipy.io.savemat('../../_data/MAT files/FWC/FWC_ANHA4_d23'+format(time, '03d')+'.mat', mdict=save_var)
    
    print('FWC_ANHA4_d23'+format(time, '03d')+'.mat')
# Out:
# allocation done
# FWC_ANHA4_d23000.mat
# FWC_ANHA4_d23001.mat
# FWC_ANHA4_d23002.mat
# FWC_ANHA4_d23003.mat
# FWC_ANHA4_d23004.mat
# FWC_ANHA4_d23005.mat
# FWC_ANHA4_d23006.mat
# FWC_ANHA4_d23007.mat
# FWC_ANHA4_d23008.mat
# FWC_ANHA4_d23009.mat
# FWC_ANHA4_d23010.mat
# FWC_ANHA4_d23011.mat
# FWC_ANHA4_d23012.mat
# FWC_ANHA4_d23013.mat
# FWC_ANHA4_d23014.mat
# FWC_ANHA4_d23015.mat
# FWC_ANHA4_d23016.mat
# FWC_ANHA4_d23017.mat
# FWC_ANHA4_d23018.mat
# FWC_ANHA4_d23019.mat
# FWC_ANHA4_d23020.mat
# FWC_ANHA4_d23021.mat
# FWC_ANHA4_d23022.mat
# FWC_ANHA4_d23023.mat
# FWC_ANHA4_d23024.mat
# FWC_ANHA4_d23025.mat
# FWC_ANHA4_d23026.mat
# FWC_ANHA4_d23027.mat
# FWC_ANHA4_d23028.mat
# FWC_ANHA4_d23029.mat
# FWC_ANHA4_d23030.mat
# FWC_ANHA4_d23031.mat
# FWC_ANHA4_d23032.mat
# FWC_ANHA4_d23033.mat
# FWC_ANHA4_d23034.mat
# FWC_ANHA4_d23035.mat
# FWC_ANHA4_d23036.mat
# FWC_ANHA4_d23037.mat
# FWC_ANHA4_d23038.mat
# FWC_ANHA4_d23039.mat
# FWC_ANHA4_d23040.mat
# FWC_ANHA4_d23041.mat
# FWC_ANHA4_d23042.mat
# FWC_ANHA4_d23043.mat
# FWC_ANHA4_d23044.mat
# FWC_ANHA4_d23045.mat
# FWC_ANHA4_d23046.mat
# FWC_ANHA4_d23047.mat
# FWC_ANHA4_d23048.mat
# FWC_ANHA4_d23049.mat
# FWC_ANHA4_d23050.mat
# FWC_ANHA4_d23051.mat
# FWC_ANHA4_d23052.mat
# FWC_ANHA4_d23053.mat
# FWC_ANHA4_d23054.mat
# FWC_ANHA4_d23055.mat
# FWC_ANHA4_d23056.mat
# FWC_ANHA4_d23057.mat
# FWC_ANHA4_d23058.mat
# FWC_ANHA4_d23059.mat
# FWC_ANHA4_d23060.mat
# FWC_ANHA4_d23061.mat
# FWC_ANHA4_d23062.mat
# FWC_ANHA4_d23063.mat
# FWC_ANHA4_d23064.mat
# FWC_ANHA4_d23065.mat
# FWC_ANHA4_d23066.mat
# FWC_ANHA4_d23067.mat
# FWC_ANHA4_d23068.mat
# FWC_ANHA4_d23069.mat
# FWC_ANHA4_d23070.mat
# FWC_ANHA4_d23071.mat
# FWC_ANHA4_d23072.mat
# FWC_ANHA4_d23073.mat
# FWC_ANHA4_d23074.mat
# FWC_ANHA4_d23075.mat
# FWC_ANHA4_d23076.mat
# FWC_ANHA4_d23077.mat
# FWC_ANHA4_d23078.mat
# FWC_ANHA4_d23079.mat
# FWC_ANHA4_d23080.mat
# FWC_ANHA4_d23081.mat
# FWC_ANHA4_d23082.mat
# FWC_ANHA4_d23083.mat
# FWC_ANHA4_d23084.mat
# FWC_ANHA4_d23085.mat
# FWC_ANHA4_d23086.mat
# FWC_ANHA4_d23087.mat
# FWC_ANHA4_d23088.mat
# FWC_ANHA4_d23089.mat
# FWC_ANHA4_d23090.mat
# FWC_ANHA4_d23091.mat
# FWC_ANHA4_d23092.mat
# FWC_ANHA4_d23093.mat
# FWC_ANHA4_d23094.mat
# FWC_ANHA4_d23095.mat
# FWC_ANHA4_d23096.mat
# FWC_ANHA4_d23097.mat
# FWC_ANHA4_d23098.mat
# FWC_ANHA4_d23099.mat
# FWC_ANHA4_d23100.mat
# FWC_ANHA4_d23101.mat
# FWC_ANHA4_d23102.mat
# FWC_ANHA4_d23103.mat
# FWC_ANHA4_d23104.mat
# FWC_ANHA4_d23105.mat
# FWC_ANHA4_d23106.mat
# FWC_ANHA4_d23107.mat
# FWC_ANHA4_d23108.mat
# FWC_ANHA4_d23109.mat
# FWC_ANHA4_d23110.mat
# FWC_ANHA4_d23111.mat
# FWC_ANHA4_d23112.mat
# FWC_ANHA4_d23113.mat
# FWC_ANHA4_d23114.mat
# FWC_ANHA4_d23115.mat
# FWC_ANHA4_d23116.mat
# FWC_ANHA4_d23117.mat
# FWC_ANHA4_d23118.mat
# FWC_ANHA4_d23119.mat
# FWC_ANHA4_d23120.mat
# FWC_ANHA4_d23121.mat
# FWC_ANHA4_d23122.mat
# FWC_ANHA4_d23123.mat
# FWC_ANHA4_d23124.mat
# FWC_ANHA4_d23125.mat
# FWC_ANHA4_d23126.mat
# FWC_ANHA4_d23127.mat
# FWC_ANHA4_d23128.mat
# FWC_ANHA4_d23129.mat
# FWC_ANHA4_d23130.mat
# FWC_ANHA4_d23131.mat
# FWC_ANHA4_d23132.mat
# FWC_ANHA4_d23133.mat
# FWC_ANHA4_d23134.mat
# FWC_ANHA4_d23135.mat
# FWC_ANHA4_d23136.mat
# FWC_ANHA4_d23137.mat
# FWC_ANHA4_d23138.mat
# FWC_ANHA4_d23139.mat
# FWC_ANHA4_d23140.mat
# FWC_ANHA4_d23141.mat
# FWC_ANHA4_d23142.mat
# FWC_ANHA4_d23143.mat
